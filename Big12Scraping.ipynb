# %%
import time
import numpy as np
import pandas as pd
import requests
import random

# %%
main_df = pd.DataFrame()

# %%
url = "https://www.sports-reference.com/cbb/conferences/big-12/men/2024.html"

# %%
r = requests.get(url)

# %%
main_df = pd.read_html(r.text, header = 1, attrs={"id": "big-12-stats"})[0]
# Out:
# C:\Users\mazin\AppData\Local\Temp\ipykernel_66752\1661049406.py:1: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   main_df = pd.read_html(r.text, header = 1, attrs={"id": "big-12-stats"})[0]

# %%
time.sleep(random.uniform(1,3))

# %%
main_df
# Out:
#     Rk          School   G   W   L     W%  W.1  L.1  W.2  L.2  ...   STL  BLK  \
# 0    1         Houston  37  32   5  0.865   15    3   17    0  ...   9.8  4.8
# 1    2      Iowa State  37  29   8  0.784   13    5   18    0  ...  10.3  3.1
# 2    3          Baylor  35  24  11  0.686   11    7   15    2  ...   6.7  3.1
# 3    4      Texas Tech  34  23  11  0.676   11    7   15    2  ...   6.0  2.5
# 4    5             BYU  34  23  11  0.676   10    8   16    2  ...   5.9  3.0
# 5    6          Kansas  34  23  11  0.676   10    8   15    1  ...   7.1  3.9
# 6    7           Texas  34  21  13  0.618    9    9   14    4  ...   7.2  4.4
# 7    8             TCU  34  21  13  0.618    9    9   12    4  ...   9.0  3.8
# 8    9    Kansas State  34  19  15  0.559    8   10   15    3  ...   5.9  4.1
# 9   10        Oklahoma  32  20  12  0.625    8   10   14    4  ...   5.9  3.3
# 10  11             UCF  33  17  16  0.515    7   11   11    8  ...   8.7  5.0
# ...

# %%
main_df.to_excel("big_12_data.xlsx", index = False)
